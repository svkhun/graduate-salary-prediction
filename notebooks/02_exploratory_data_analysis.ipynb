# %%
import pandas as pd

# โหลดข้อมูล
df = pd.read_csv("D3_student_placement_prediction_dataset_2026 (1).csv")

# เลือกเฉพาะตัวแปรที่เราสนใจ
columns = [
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]

data = df[columns]

# ดูสถิติพื้นฐาน
stats = data.describe()

print(stats)
# Out:
#        aptitude_score  coding_skill_score  communication_skill_score  \
# count   100000.000000       100000.000000              100000.000000
# mean        64.988108           69.825326                  67.960744
# std         14.844093           14.694618                  13.846636
# min         20.000000           20.000000                  20.000000
# 25%         54.894600           59.807945                  58.587535
# 50%         65.011394           70.006250                  67.973221
# 75%         75.079266           80.058762                  77.503749
# max        100.000000          100.000000                 100.000000
#
#        logical_reasoning_score  salary_package_lpa
# count            100000.000000       100000.000000
# mean                 65.931696            7.252106
# std                  14.826790            6.735132
# min                  20.000000            0.000000
# 25%                  55.940547            0.000000
# ...

# %% [markdown]
# เรียงข้อมูล

# %%
summary = data.describe().T
print(summary)
# Out:
#                               count       mean        std   min        25%  \
# aptitude_score             100000.0  64.988108  14.844093  20.0  54.894600
# coding_skill_score         100000.0  69.825326  14.694618  20.0  59.807945
# communication_skill_score  100000.0  67.960744  13.846636  20.0  58.587535
# logical_reasoning_score    100000.0  65.931696  14.826790  20.0  55.940547
# salary_package_lpa         100000.0   7.252106   6.735132   0.0   0.000000
#
#                                  50%        75%     max
# aptitude_score             65.011394  75.079266  100.00
# coding_skill_score         70.006250  80.058762  100.00
# communication_skill_score  67.973221  77.503749  100.00
# logical_reasoning_score    66.003829  76.113705  100.00
# salary_package_lpa         11.100000  13.470000   20.44

# %% [markdown]
# ดูการกระจายของข้อมูล

# %%
import pandas as pd
import matplotlib.pyplot as plt

# โหลดข้อมูล
df = pd.read_csv("D3_student_placement_prediction_dataset_2026 (1).csv")

columns = [
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]

# วาด histogram
for col in columns:
    plt.figure()
    plt.hist(df[col], bins=30)
    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %%
import seaborn as sns

for col in columns:
    plt.figure()
    sns.histplot(df[col], kde=True)
    plt.title(f"Distribution of {col}")
    plt.show()

# %% [markdown]
# ดูความสัมพันธ์ของตัวแปร

# %%
import pandas as pd
import matplotlib.pyplot as plt

# โหลดข้อมูล
df = pd.read_csv("D3_student_placement_prediction_dataset_2026 (1).csv")

features = [
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score"
]

target = "salary_package_lpa"

# สร้าง scatter plot
for col in features:
    plt.figure()
    plt.scatter(df[col], df[target])
    plt.title(f"{col} vs {target}")
    plt.xlabel(col)
    plt.ylabel(target)
    plt.show()

# %%
import seaborn as sns

for col in features:
    plt.figure()
    sns.regplot(x=df[col], y=df[target])
    plt.title(f"{col} vs {target}")
    plt.show()

# %% [markdown]
# ตรวจสอบ count

# %%
print("Total rows:", len(df))
# Out:
# Total rows: 100000

# %%
df.shape
# Out:
# (100000, 26)

# %%
df[[
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]].count()
# Out:
# aptitude_score               100000
# coding_skill_score           100000
# communication_skill_score    100000
# logical_reasoning_score      100000
# salary_package_lpa           100000
# dtype: int64

# %%
df[[
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]].isnull().sum()
# Out:
# aptitude_score               0
# coding_skill_score           0
# communication_skill_score    0
# logical_reasoning_score      0
# salary_package_lpa           0
# dtype: int64

# %%
summary = df[[
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]].agg(['count', 'size', 'nunique'])

print(summary)
# Out:
#          aptitude_score  coding_skill_score  communication_skill_score  \
# count            100000              100000                     100000
# size             100000              100000                     100000
# nunique           98859               97643                      98872
#
#          logical_reasoning_score  salary_package_lpa
# count                     100000              100000
# size                      100000              100000
# nunique                    98730                1047

# %%
summary = pd.DataFrame({
    "Total_rows": len(df),
    "Non_missing": df.count(),
    "Missing": df.isnull().sum()
})

print(summary)
# Out:
#                            Total_rows  Non_missing  Missing
# student_id                     100000       100000        0
# age                            100000       100000        0
# gender                         100000       100000        0
# cgpa                           100000       100000        0
# branch                         100000       100000        0
# college_tier                   100000       100000        0
# internships_count              100000       100000        0
# projects_count                 100000       100000        0
# certifications_count           100000       100000        0
# coding_skill_score             100000       100000        0
# aptitude_score                 100000       100000        0
# communication_skill_score      100000       100000        0
# logical_reasoning_score        100000       100000        0
# hackathons_participated        100000       100000        0
# github_repos                   100000       100000        0
# ...

# %% [markdown]
# reset step 2

# %%
print(df["placement_status"].value_counts())
# Out:
# placement_status
# Placed        54459
# Not Placed    45541
# Name: count, dtype: int64

# %% [markdown]
# ตรวจสอบ Salary ของแต่ละกลุ่ม

# %%
df.groupby("placement_status")["salary_package_lpa"].describe()
# Out:
#                     count       mean       std   min    25%   50%    75%  \
# placement_status
# Not Placed        45541.0   0.000000  0.000000  0.00   0.00   0.0   0.00
# Placed            54459.0  13.316635  1.592418  7.11  12.23  13.3  14.39
#
#                     max
# placement_status
# Not Placed         0.00
# Placed            20.44

# %%
df_placed = df[df["placement_status"] == "Placed"]

# %%
columns = [
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]

df_placed[columns].describe()
# Out:
#        aptitude_score  coding_skill_score  communication_skill_score  \
# count    54459.000000        54459.000000               54459.000000
# mean        65.418276           70.507598                  68.368999
# std         14.837443           14.620091                  13.856462
# min         20.000000           20.000000                  20.000000
# 25%         55.323007           60.530369                  58.981559
# 50%         65.469800           70.732405                  68.440795
# 75%         75.439412           80.759221                  77.926139
# max        100.000000          100.000000                 100.000000
#
#        logical_reasoning_score  salary_package_lpa
# count             54459.000000        54459.000000
# mean                 66.424298           13.316635
# std                  14.763197            1.592418
# min                  20.000000            7.110000
# 25%                  56.417580           12.230000
# ...

# %%
print(df["salary_package_lpa"].value_counts().head(10))
# Out:
# salary_package_lpa
# 0.00     45541
# 13.58      154
# 13.18      153
# 13.45      151
# 12.99      151
# 13.28      149
# 12.70      149
# 13.92      149
# 12.76      148
# 13.14      147
# Name: count, dtype: int64

# %%
df_placed = df[df["salary_package_lpa"] > 0]

# %%
df_placed = df[df["salary_package_lpa"] > 0]

columns = [
    "aptitude_score",
    "coding_skill_score",
    "communication_skill_score",
    "logical_reasoning_score",
    "salary_package_lpa"
]

summary = df_placed[columns].describe().T
print(summary)
# Out:
#                              count       mean        std    min        25%  \
# aptitude_score             54459.0  65.418276  14.837443  20.00  55.323007
# coding_skill_score         54459.0  70.507598  14.620091  20.00  60.530369
# communication_skill_score  54459.0  68.368999  13.856462  20.00  58.981559
# logical_reasoning_score    54459.0  66.424298  14.763197  20.00  56.417580
# salary_package_lpa         54459.0  13.316635   1.592418   7.11  12.230000
#
#                                  50%        75%     max
# aptitude_score             65.469800  75.439412  100.00
# coding_skill_score         70.732405  80.759221  100.00
# communication_skill_score  68.440795  77.926139  100.00
# logical_reasoning_score    66.451542  76.610590  100.00
# salary_package_lpa         13.300000  14.390000   20.44
